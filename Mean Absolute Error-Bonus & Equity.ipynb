# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
fpath = 'salaries_modified.csv'
fpath2 = 'salary.csv'

# %%
df_cleaned = pd.read_csv(fpath)
df = pd.read_csv(fpath2)
df
# Out:
#                 timestamp              company  level           title  \
# 0     2018-06-05 14:06:30             LinkedIn    5.0  Data Scientist
# 1     2018-06-08 00:29:47               Amazon    4.0  Data Scientist
# 2     2018-06-08 09:49:25            Microsoft   64.0  Data Scientist
# 3     2018-06-08 17:55:09                 ebay   26.0  Data Scientist
# 4     2018-06-10 19:39:35              Twitter    4.0  Data Scientist
# ...                   ...                  ...    ...             ...
# 2051  2021-08-15 22:31:26                Adobe    3.0  Data Scientist
# 2052  2021-08-16 16:17:19                  IBM    5.0  Data Scientist
# 2053  2021-08-16 17:08:58  Booz Allen Hamilton    5.0  Data Scientist
# 2054  2021-08-16 21:02:37                Xandr    1.0  Data Scientist
# 2055  2021-08-16 22:19:48             Facebook    4.0  Data Scientist
#
#       totalyearlycompensation  yearsofexperience  yearsatcompany  \
# ...

# %%
bonus_mean = df_cleaned.bonus.mean()
equity_mean = df_cleaned.stockgrantvalue.mean()

# %%
df['b_mean'] = bonus_mean
df['e_mean'] = equity_mean
df.head()
# Out:
#              timestamp    company  level           title  \
# 0  2018-06-05 14:06:30   LinkedIn    5.0  Data Scientist
# 1  2018-06-08 00:29:47     Amazon    4.0  Data Scientist
# 2  2018-06-08 09:49:25  Microsoft   64.0  Data Scientist
# 3  2018-06-08 17:55:09       ebay   26.0  Data Scientist
# 4  2018-06-10 19:39:35    Twitter    4.0  Data Scientist
#
#    totalyearlycompensation  yearsofexperience  yearsatcompany  \
# 0                    233.0                4.0             0.0
# 1                    140.0                2.0             2.0
# 2                    218.0               11.0            11.0
# 3                    180.0               10.0             5.0
# 4                    500.0                4.0             4.0
#
#    stockgrantvalue  bonus           city state country     b_mean     e_mean
# 0            220.0   10.0  San Francisco    CA      US  18.511436  46.851582
# 1          48000.0    0.0        Seattle    WA      US  18.511436  46.851582
# ...

# %%
b_y_true = df.bonus
b_y_pred = df.b_mean
e_y_true = df.stockgrantvalue
e_y_pred = df.e_mean

# %%
b_MAE = mean_absolute_error(b_y_true,b_y_pred)
b_MAE
# Out:
# 69.01087955731019

# %%
e_MAE = mean_absolute_error(e_y_true,e_y_pred)
e_MAE
# Out:
# 594.4972852585041
